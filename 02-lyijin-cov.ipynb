# %%
# !ls lyijin-cov/*cov
# Out:
# lyijin-cov/spis_pH_7.2A.final.annot.cov lyijin-cov/spis_pH_7.8A.final.annot.cov
# lyijin-cov/spis_pH_7.2B.final.annot.cov lyijin-cov/spis_pH_7.8B.final.annot.cov
# lyijin-cov/spis_pH_7.2C.final.annot.cov lyijin-cov/spis_pH_7.8C.final.annot.cov
# lyijin-cov/spis_pH_7.4A.final.annot.cov lyijin-cov/spis_pH_8.1A.final.annot.cov
# lyijin-cov/spis_pH_7.4B.final.annot.cov lyijin-cov/spis_pH_8.1B.final.annot.cov
# lyijin-cov/spis_pH_7.4C.final.annot.cov lyijin-cov/spis_pH_8.1C.final.annot.cov

# %%
# !head lyijin-cov/*cov
# Out:
# ==> lyijin-cov/spis_pH_7.2A.final.annot.cov <==
# Spis.scaffold1|size2969787	8660	8660	69.2307692307692	9	4	SpisGene1	0.17083	1525	-7405	Intron_2_-11	0.82705	1030	-216
# Spis.scaffold1|size2969787	8661	8661	81.25	13	3	SpisGene1	0.17094	1526	-7404	Intron_2_-11	0.82785	1031	-215
# Spis.scaffold1|size2969787	8726	8726	20	3	12	SpisGene1	0.17822	1591	-7339	Intron_2_-11	0.88002	1096	-150
# Spis.scaffold1|size2969787	8727	8727	21.0526315789474	4	15	SpisGene1	0.17833	1592	-7338	Intron_2_-11	0.88082	1097	-149
# Spis.scaffold1|size2969787	8884	8884	92.8571428571429	13	1	SpisGene1	0.19591	1749	-7181	Exon_3_-11	0.068	8	-117
# Spis.scaffold1|size2969787	8885	8885	81.25	13	3	SpisGene1	0.19602	1750	-7180	Exon_3_-11	0.076	9	-116
# Spis.scaffold1|size2969787	8931	8931	57.1428571428571	8	6	SpisGene1	0.20118	1796	-7134	Exon_3_-11	0.444	55	-70
# Spis.scaffold1|size2969787	8932	8932	66.6666666666667	12	6	SpisGene1	0.20129	1797	-7133	Exon_3_-11	0.452	56	-69
# ...

# %%
# !awk '{print $1}' lyijin-cov/spis_pH_8.1C.final.annot.cov | head
# Out:
# Spis.scaffold1|size2969787
# Spis.scaffold1|size2969787
# Spis.scaffold1|size2969787
# Spis.scaffold1|size2969787
# Spis.scaffold1|size2969787
# Spis.scaffold1|size2969787
# Spis.scaffold1|size2969787
# Spis.scaffold1|size2969787
# Spis.scaffold1|size2969787
# Spis.scaffold1|size2969787
# awk: write error on /dev/stdout
#  input record number 1214, file lyijin-cov/spis_pH_8.1C.final.annot.cov
#  source line number 1

# %%
# !head ../analyses/

# %%
cd lyijin-cov/
# Out:
# /Users/sr320/Documents/GitHub/molecular-prelim/lyijin-cov

# %%
# %%bash
# for f in *annot.cov
# do
#   STEM=$(basename "${f}" .final.annot.cov)
#   cat "${f}" | awk -F $'\t' 'BEGIN {OFS = FS} {print $1, $2, $3, $4}' \
#   > ../analyses/"${STEM}".bedgraph
# done

# %%
# !head ../analyses/*bedgraph
# Out:
# ==> ../analyses/spis_pH_7.2A.bedgraph <==
# Spis.scaffold1|size2969787	8660	8660	69.2307692307692
# Spis.scaffold1|size2969787	8661	8661	81.25
# Spis.scaffold1|size2969787	8726	8726	20
# Spis.scaffold1|size2969787	8727	8727	21.0526315789474
# Spis.scaffold1|size2969787	8884	8884	92.8571428571429
# Spis.scaffold1|size2969787	8885	8885	81.25
# Spis.scaffold1|size2969787	8931	8931	57.1428571428571
# Spis.scaffold1|size2969787	8932	8932	66.6666666666667
# Spis.scaffold1|size2969787	9080	9080	65
# Spis.scaffold1|size2969787	9081	9081	72.2222222222222
#
# ==> ../analyses/spis_pH_7.2B.bedgraph <==
# Spis.scaffold1|size2969787	8660	8660	69.5652173913043
# Spis.scaffold1|size2969787	8661	8661	47.0588235294118
# Spis.scaffold1|size2969787	8726	8726	28.5714285714286
# Spis.scaffold1|size2969787	8727	8727	23.0769230769231
# Spis.scaffold1|size2969787	8884	8884	80.9523809523809
# Spis.scaffold1|size2969787	8885	8885	85.7142857142857
# Spis.scaffold1|size2969787	8931	8931	45.8333333333333
# ...
